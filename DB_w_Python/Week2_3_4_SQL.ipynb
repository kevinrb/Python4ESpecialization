# %%
import sqlite3
conn = sqlite3.connect('DBs/sql1.db')
cur = conn.cursor()
cur.execute("select * from Counts")
row = cur.fetchone()
print(row)
cur.close()
# Out:
# None

# %%
import sqlite3
sqlite_file = 'db.sqlite'
conn = sqlite3.connect(sqlite_file)
cur = conn.cursor()

cur.execute('DROP TABLE IF EXISTS Counts')

cur.execute('CREATE TABLE Counts (org  TEXT, count INTEGER)')

fname = 'mbox.txt'
fh = open(fname)
dict_domain = dict()
for line in fh:
    if not line.startswith('From: '): continue
    pieces = line.split()
    domain = pieces[1].split("@")[1]
    dict_domain[domain] = dict_domain.get(domain,0)+1

for k,v in dict_domain.items():
     cur.execute('INSERT INTO Counts (org , count) VALUES (?, ?)', (k,v))
conn.commit()
sqlstr = 'SELECT org , count FROM Counts ORDER BY count DESC LIMIT 10'

for row in cur.execute(sqlstr):
    print(str(row[0]), row[1])

cur.close()
# Out:
# iupui.edu 536
# umich.edu 491
# indiana.edu 178
# caret.cam.ac.uk 157
# vt.edu 110
# uct.ac.za 96
# media.berkeley.edu 56
# ufp.pt 28
# gmail.com 25
# et.gatech.edu 17

# %%
import sqlite3
import xml.etree.ElementTree as ET

sqlite_file = 'db2.sqlite'
conn = sqlite3.connect(sqlite_file)
cur = conn.cursor()

cur.executescript('''
DROP TABLE IF EXISTS Artist;
DROP TABLE IF EXISTS Genre;
DROP TABLE IF EXISTS Album;
DROP TABLE IF EXISTS Track;

CREATE TABLE Artist (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name    TEXT UNIQUE
);

CREATE TABLE Genre (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name    TEXT UNIQUE
);

CREATE TABLE Album (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    artist_id  INTEGER,
    title   TEXT UNIQUE
);

CREATE TABLE Track (
    id  INTEGER NOT NULL PRIMARY KEY 
        AUTOINCREMENT UNIQUE,
    title TEXT  UNIQUE,
    album_id  INTEGER,
    genre_id  INTEGER,
    len INTEGER, rating INTEGER, count INTEGER
);

''');

def lookup(d, key):
    found = False
    for child in d:
        if found : return child.text
        if child.tag == 'key' and child.text == key :
            found = True
    return None

fname = 'Library.xml'
fh = open(fname)
    
stuff = ET.parse(fname)
all = stuff.findall('dict/dict/dict')
for entry in all:
    if ( lookup(entry, 'Track ID') is None ) : continue

    name = lookup(entry, 'Name')
    artist = lookup(entry, 'Artist')
    album = lookup(entry, 'Album')
    count = lookup(entry, 'Play Count')
    rating = lookup(entry, 'Rating')
    length = lookup(entry, 'Total Time')
    genre = lookup(entry, 'Genre')
    if name is None or artist is None or album is None or genre is None : 
        continue
    
    
    cur.execute('''INSERT OR IGNORE INTO Artist (name) 
        VALUES ( ? )''', ( artist, ) )
    cur.execute('SELECT id FROM Artist WHERE name = ? ', (artist, ))
    artist_id = cur.fetchone()[0]
    
    cur.execute('''INSERT OR IGNORE INTO Genre (name) 
        VALUES ( ? )''', ( genre, ) )
    cur.execute('SELECT id FROM Genre WHERE name = ? ', (genre, ))
    genre_id = cur.fetchone()[0]

    cur.execute('''INSERT OR IGNORE INTO Album (title, artist_id) 
        VALUES ( ?, ? )''', ( album, artist_id ) )
    cur.execute('SELECT id FROM Album WHERE title = ? ', (album, ))
    album_id = cur.fetchone()[0]

    cur.execute('''INSERT OR REPLACE INTO Track
        (title, album_id, len, rating, count, genre_id) 
        VALUES ( ?, ?, ?, ?, ?, ? )''', 
        ( name, album_id, length, rating, count, genre_id) )

conn.commit()

sqlstr = '''
SELECT Track.title, Artist.name, Album.title, Genre.name 
    FROM Track JOIN Genre JOIN Album JOIN Artist 
    ON Track.genre_id = Genre.ID and Track.album_id = Album.id 
        AND Album.artist_id = Artist.id
    ORDER BY Artist.name,Track.title LIMIT 3
'''

for row in cur.execute(sqlstr):
    print(str(row[0]), row[1], row[2], row[3])

cur.close()
# Out:
# Chase the Ace AC/DC Who Made Who Rock
# D.T. AC/DC Who Made Who Rock
# For Those About To Rock (We Salute You) AC/DC Who Made Who Rock

# %%
import json
import sqlite3

conn = sqlite3.connect('db3.sqlite')
cur = conn.cursor()

# Do some setup
cur.executescript('''
DROP TABLE IF EXISTS User;
DROP TABLE IF EXISTS Member;
DROP TABLE IF EXISTS Course;

CREATE TABLE User (
    id     INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name   TEXT UNIQUE
);

CREATE TABLE Course (
    id     INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    title  TEXT UNIQUE
);

CREATE TABLE Member (
    user_id     INTEGER,
    course_id   INTEGER,
    role        INTEGER,
    PRIMARY KEY (user_id, course_id)
)
''')

fname = 'roster_data.json'


str_data = open(fname).read()
json_data = json.loads(str_data)

for entry in json_data:

    name = entry[0];
    title = entry[1];
    role = entry[2];

    print((name, title,role))

    cur.execute('''INSERT OR IGNORE INTO User (name)
        VALUES ( ? )''', ( name, ) )
    cur.execute('SELECT id FROM User WHERE name = ? ', (name, ))
    user_id = cur.fetchone()[0]

    cur.execute('''INSERT OR IGNORE INTO Course (title)
        VALUES ( ? )''', ( title, ) )
    cur.execute('SELECT id FROM Course WHERE title = ? ', (title, ))
    course_id = cur.fetchone()[0]

    cur.execute('''INSERT OR REPLACE INTO Member
        (user_id, course_id, role) VALUES ( ?, ?, ? )''',
        ( user_id, course_id, role ) )


conn.commit()
    
sqlstr = '''
SELECT hex(User.name || Course.title || Member.role ) AS X FROM 
    User JOIN Member JOIN Course 
    ON User.id = Member.user_id AND Member.course_id = Course.id
    ORDER BY X
'''

for row in cur.execute(sqlstr):
    print(str(row[0]))

cur.close()
# Out:
# ('Seane', 'si110', 1)
# ('Saghun', 'si110', 0)
# ('Cooper', 'si110', 0)
# ('Norman', 'si110', 0)
# ('Lavinia', 'si110', 0)
# ('Lani', 'si110', 0)
# ('Gustav', 'si110', 0)
# ('Vladislav', 'si110', 0)
# ('Alivia', 'si110', 0)
# ('Kyalah', 'si110', 0)
# ('Islay', 'si110', 0)
# ('Oryn', 'si110', 0)
# ('Nicki', 'si110', 0)
# ('Moshy', 'si110', 0)
# ('Jill', 'si110', 0)
# ('Kaya', 'si110', 0)
# ('Kaydee', 'si110', 0)
# ('Deshawn', 'si110', 0)
# ('Howie', 'si110', 0)
# ('Malachy', 'si110', 0)
# ('Brajan', 'si110', 0)
# ('Mili', 'si110', 0)
# ('Kaidi', 'si110', 0)
# ('Manwen', 'si110', 0)
# ('Garren', 'si110', 0)
# ('Digby', 'si110', 0)
# ('Kiya', 'si110', 0)
# ('Martyn', 'si110', 0)
# ('Orley', 'si110', 0)
# ('Jaydon', 'si110', 0)
# ('Konrad', 'si110', 0)
# ('Veronika', 'si110', 0)
# ('Nyah', 'si110', 0)
# ('Nassir', 'si110', 0)
# ('Annalisa', 'si110', 0)
# ('Safiya', 'si106', 1)
# ('Ramsey', 'si106', 0)
# ('Jasmine', 'si106', 0)
# ('Jebadiah', 'si106', 0)
# ('Annalise', 'si106', 0)
# ('Nicki', 'si106', 0)
# ('Evan', 'si106', 0)
# ('Lauryn', 'si106', 0)
# ('Jaymie', 'si106', 0)
# ('Marcelina', 'si106', 0)
# ('Hannah', 'si106', 0)
# ('Helen', 'si106', 0)
# ('Kyran', 'si106', 0)
# ('Saanvi', 'si106', 0)
# ('Jaelyn', 'si106', 0)
# ('Maisum', 'si106', 0)
# ('Farrah', 'si106', 0)
# ('Zinto', 'si106', 0)
# ('Karandeep', 'si106', 0)
# ('Shaw', 'si106', 0)
# ('Stephanie', 'si106', 0)
# ('Robyn', 'si106', 0)
# ('Josephina', 'si106', 0)
# ('Marina', 'si106', 0)
# ('Brodi', 'si106', 0)
# ('Shane', 'si106', 0)
# ('Jolie', 'si106', 0)
# ('Juliette', 'si106', 0)
# ('Cael', 'si106', 0)
# ('Kevaugh', 'si106', 0)
# ('Elissa', 'si106', 0)
# ('Yang', 'si106', 0)
# ('Tiffany', 'si106', 0)
# ('Preston', 'si106', 0)
# ('Miah', 'si106', 0)
# ('Laticha', 'si206', 1)
# ('Shaurya', 'si206', 0)
# ('Jaeden', 'si206', 0)
# ('Darci', 'si206', 0)
# ('Bruce', 'si206', 0)
# ('Sameera', 'si206', 0)
# ('Marian', 'si206', 0)
# ('Safiya', 'si206', 0)
# ('Guang', 'si206', 0)
# ('Abdalroof', 'si206', 0)
# ('Leah', 'si206', 0)
# ('Somaya', 'si206', 0)
# ('Nabeeha', 'si206', 0)
# ('Josef', 'si206', 0)
# ('Eisha', 'si206', 0)
# ('Charley', 'si206', 0)
# ('Zaynab', 'si206', 0)
# ('Loui', 'si206', 0)
# ('Keiara', 'si206', 0)
# ('Eroni', 'si206', 0)
# ('Alesha', 'si206', 0)
# ('Ada', 'si206', 0)
# ('Arnold', 'si206', 0)
# ('Jian', 'si206', 0)
# ('Marcie', 'si206', 0)
# ('Coll', 'si206', 0)
# ('Daniyal', 'si206', 0)
# ('Surya', 'si206', 0)
# ('Harnisha', 'si206', 0)
# ('Amalia', 'si206', 0)
# ('Jaydn', 'si206', 0)
# ('Neshawn', 'si206', 0)
# ('Kruz', 'si206', 0)
# ('Cecily', 'si206', 0)
# ('Eugene', 'si206', 0)
# ('Lucie', 'si301', 1)
# ('Chukwuemeka', 'si301', 0)
# ('Jarl', 'si301', 0)
# ('Soul', 'si301', 0)
# ('Rodrigo', 'si301', 0)
# ('Conlly', 'si301', 0)
# ('Bismah', 'si301', 0)
# ('Aliza', 'si301', 0)
# ('Heather', 'si301', 0)
# ('Diaz', 'si301', 0)
# ('Lewis', 'si301', 0)
# ('Hafsa', 'si301', 0)
# ('Dilano', 'si301', 0)
# ('Ikemsinachukwu', 'si301', 0)
# ('Amira', 'si301', 0)
# ('Demira', 'si301', 0)
# ('Rylie', 'si301', 0)
# ('Kirk', 'si301', 0)
# ('Iria', 'si301', 0)
# ('Kale', 'si301', 0)
# ('Alina', 'si301', 0)
# ('Madelaine', 'si301', 0)
# ('Derri', 'si301', 0)
# ('Kelvin', 'si301', 0)
# ('Adrian', 'si301', 0)
# ('Marisa', 'si301', 0)
# ('Mhyren', 'si301', 0)
# ('Ekaterina', 'si301', 0)
# ('Iliana', 'si301', 0)
# ('Siriol', 'si301', 0)
# ('Tate', 'si301', 0)
# ('Amaylyuh', 'si301', 0)
# ('Dhavid', 'si301', 0)
# ('Avesta', 'si310', 1)
# ('Juan', 'si310', 0)
# ('Elli', 'si310', 0)
# ('Iris', 'si310', 0)
# ('Dalton', 'si310', 0)
# ('Zander', 'si310', 0)
# ('Alva', 'si310', 0)
# ('Jaida', 'si310', 0)
# ('Ellise', 'si310', 0)
# ('Hayley', 'si310', 0)
# ('Lyall', 'si310', 0)
# ('Maree', 'si310', 0)
# ('Dre', 'si310', 0)
# ('Katelynn', 'si310', 0)
# ('Zeinab', 'si310', 0)
# ('Zayne', 'si310', 0)
# ('Andra', 'si310', 0)
# ('Deecan', 'si310', 0)
# ('Ceirin', 'si310', 0)
# ('Tara', 'si310', 0)
# ('Rubie', 'si310', 0)
# ('Brenna', 'si310', 0)
# ('Dillon', 'si310', 0)
# ('Hazel', 'si310', 0)
# ('Ngaire', 'si310', 0)
# ('Abbeygail', 'si310', 0)
# ('Nafeesa', 'si310', 0)
# ('Bradlie', 'si310', 0)
# ('Aya', 'si310', 0)
# ('Sakina', 'si310', 0)
# ('Isa', 'si310', 0)
# ('Darius', 'si310', 0)
# ('Mila', 'si310', 0)
# ('Masood', 'si310', 0)
# ('Samar', 'si310', 0)
# ('Loxi', 'si310', 0)
# ('Moad', 'si310', 0)
# ('Caera', 'si310', 0)
# ('Karine', 'si310', 0)
# ('Angelika', 'si310', 0)
# ('Ricco', 'si310', 0)
# ('Amirah', 'si310', 0)
# ('Rafael', 'si310', 0)
# ('Zachery', 'si310', 0)
# ('Brajan', 'si310', 0)
# ('Carley', 'si310', 0)
# ('Riyaj', 'si310', 0)
# ('Davina', 'si310', 0)
# ('Mateusz', 'si310', 0)
# ('Dexter', 'si310', 0)
# ('Kodie', 'si310', 0)
# ('Elen', 'si334', 1)
# ('Zeph', 'si334', 0)
# ('Eassan', 'si334', 0)
# ('Karn', 'si334', 0)
# ('Caedan', 'si334', 0)
# ('Cooper', 'si334', 0)
# ('Susan', 'si334', 0)
# ('Fyfe', 'si334', 0)
# ('Nikiya', 'si334', 0)
# ('Aayan', 'si334', 0)
# ('Eirini', 'si334', 0)
# ('Freia', 'si334', 0)
# ('Sherwyn', 'si334', 0)
# ('Freddie', 'si334', 0)
# ('Rebeka', 'si334', 0)
# ('Nicole', 'si334', 0)
# ('Danelle', 'si334', 0)
# ('Arella', 'si334', 0)
# ('Kenzie', 'si334', 0)
# ('Bill', 'si334', 0)
# ('Beinn', 'si334', 0)
# ('Basile', 'si334', 0)
# ('Hussain', 'si334', 0)
# ('Kuba', 'si334', 0)
# ('Yu', 'si334', 0)
# ('Sadiqa', 'si334', 0)
# ('Afrina', 'si334', 0)
# ('Honeyjac', 'si334', 0)
# ('Bentley', 'si334', 0)
# ('Jayden', 'si334', 0)
# ('Kain', 'si334', 0)
# ('Celsi', 'si334', 0)
# ('Talon', 'si334', 0)
# ('Sonni', 'si334', 0)
# ('Kendyl', 'si334', 0)
# ('Betsy', 'si334', 0)
# ('Camille', 'si334', 0)
# ('Kit', 'si334', 0)
# ('Charly', 'si334', 0)
# ('Michaela', 'si334', 0)
# ('Inemesit', 'si334', 0)
# ('Alysa', 'si363', 1)
# ('Martyn', 'si363', 0)
# ('Alum', 'si363', 0)
# ('Lucinda', 'si363', 0)
# ('Urban', 'si363', 0)
# ('Karamvir', 'si363', 0)
# ('Shayne', 'si363', 0)
# ('Aaryn', 'si363', 0)
# ('Lilliana', 'si363', 0)
# ('Alan', 'si363', 0)
# ('Amber', 'si363', 0)
# ('Mathilda', 'si363', 0)
# ('Abigael', 'si363', 0)
# ('Aytug', 'si363', 0)
# ('Jacky', 'si363', 0)
# ('Rubhan', 'si363', 0)
# ('Rhuan', 'si363', 0)
# ('Lexy', 'si363', 0)
# ('Landon', 'si364', 1)
# ('Madisson', 'si364', 0)
# ('Mahek', 'si364', 0)
# ('Sommer', 'si364', 0)
# ('Artem', 'si364', 0)
# ('Rhuaridh', 'si364', 0)
# ('Yasin', 'si364', 0)
# ('Micaila', 'si364', 0)
# ('Oakley', 'si364', 0)
# ('Anir', 'si364', 0)
# ('Fabian', 'si364', 0)
# ('Atal', 'si364', 0)
# ('Cherry', 'si364', 0)
# ('Mollie', 'si364', 0)
# ('Murrough', 'si364', 0)
# ('Clodagh', 'si364', 0)
# ('Domhnall', 'si364', 0)
# ('Diesel', 'si364', 0)
# ('Harriet', 'si364', 0)
# ('Johnjay', 'si364', 0)
# ('Cacie', 'si364', 0)
# ('Lybi', 'si364', 0)
# ('Muireann', 'si364', 0)
# ('Choco', 'si364', 0)
# ('Darryn', 'si364', 0)
# ('Lanna', 'si364', 0)
# ('Uri', 'si364', 0)
# ('Kasandra', 'si364', 0)
# ('Cavan', 'si364', 0)
# ('Alix', 'si364', 0)
# ('Aoibheann', 'si364', 0)
# ('Maighdlin', 'si364', 0)
# ('Ilsa', 'si364', 0)
# ('Deshawn', 'si364', 0)
# ('Zakiyya', 'si364', 0)
# ('Kaelan', 'si364', 0)
# ('Tayye', 'si364', 0)
# ('Tieghan', 'si364', 0)
# ('Alanah', 'si364', 0)
# ('Luka', 'si422', 1)
# ('Dhara', 'si422', 0)
# ('Iman', 'si422', 0)
# ('Wardah', 'si422', 0)
# ('Allana', 'si422', 0)
# ('Didier', 'si422', 0)
# ('Corrin', 'si422', 0)
# ('Cassieleigh', 'si422', 0)
# ('Rayyan', 'si422', 0)
# ('Kassidy', 'si422', 0)
# ('Abdulbasir', 'si422', 0)
# ('Victory', 'si422', 0)
# ('Cadence', 'si422', 0)
# ('Nontando', 'si422', 0)
# ('Ammar', 'si422', 0)
# ('Kaley', 'si422', 0)
# ('Rhiannnon', 'si422', 0)
# ('Sineidin', 'si422', 0)
# ('Paislie', 'si422', 0)
# ('Zaine', 'si422', 0)
# ('Lauchlin', 'si422', 0)
# ('Minnette', 'si422', 0)
# ('Bryn', 'si422', 0)
# ('Flynn', 'si422', 0)
# ('Tanner', 'si422', 0)
# ('Lucie', 'si422', 0)
# ('Thomas', 'si422', 0)
# ('Riccardo', 'si422', 0)
# ('Oluwatamilore', 'si422', 0)
# ('Shannon', 'si422', 0)
# ('Shola', 'si422', 0)
# ('Nikos', 'si422', 0)
# ('Zenith', 'si422', 0)
# ('Satveer', 'si422', 0)
# ('Okeoghene', 'si422', 0)
# ('Ashwin', 'si422', 0)
# ('Mackie', 'si422', 0)
# ('Abel', 'si422', 0)
# ('Kisha', 'si422', 0)
# ('Daksh', 'si422', 0)
# ('Quinn', 'si422', 0)
# ('Madox', 'si422', 0)
# ('Shadow', 'si422', 0)
# ('Maneet', 'si430', 1)
# ('Keeton', 'si430', 0)
# ('Taisha', 'si430', 0)
# ('Bronwen', 'si430', 0)
# ('Levy', 'si430', 0)
# ('Kalia', 'si430', 0)
# ('Zhen', 'si430', 0)
# ('Saifaddine', 'si430', 0)
# ('Christabel', 'si430', 0)
# ('Darci', 'si430', 0)
# ('Aliyaan', 'si430', 0)
# ('Tyra', 'si430', 0)
# ('Viktoria', 'si430', 0)
# ('Benji', 'si430', 0)
# ('Oluwanifemi', 'si430', 0)
# ('Harleigh', 'si430', 0)
# ('Jayden', 'si430', 0)
# ('Inayah', 'si430', 0)
# ('Zidane', 'si430', 0)
# ('Lumi', 'si430', 0)
# 416172796E736933363330
# 416179616E736933333430
# 41626265796761696C736933313030
# 416264616C726F6F66736932303630
# 416264756C6261736972736934323230
# 4162656C736934323230
# 4162696761656C736933363330
# 416461736932303630
# 41647269616E736933303130
# 416672696E61736933333430
# 416C616E6168736933363430
# 4D617468696C6461736933363330
# 4D687972656E736933303130
# 4D696168736931303630
# 4D696361696C61736933363430
# 4D69636861656C61736933333430
# 4D696C61736933313030
# 4D696C69736931313030
# 4D696E6E65747465736934323230
# 4D6F6164736933313030
# 4D6F6C6C6965736933363430
# 4D6F736879736931313030
# 4D75697265616E6E736933363430
# 4D7572726F756768736933363430
# 4E616265656861736932303630
# 4E616665657361736933313030
# 4E6173736972736931313030
# 4E65736861776E736932303630
# 4E6761697265736933313030
# 4E69636B69736931303630
# 4E69636B69736931313030
# 4E69636F6C65736933333430
# 4E696B697961736933333430
# 4E696B6F73736934323230
# 4E6F6E74616E646F736934323230
# 4E6F726D616E736931313030
# 4E796168736931313030
# 4F616B6C6579736933363430
# 4F6B656F6768656E65736934323230
# 4F6C7577616E6966656D69736934333030
# 4F6C75776174616D696C6F7265736934323230
# 4F726C6579736931313030
# 4F72796E736931313030
# 506169736C6965736934323230
# 50726573746F6E736931303630
# 5175696E6E736934323230
# 52616661656C736933313030
# 52616D736579736931303630
# 52617979616E736934323230
# 526562656B61736933333430
# 526869616E6E6E6F6E736934323230
# 526875616E736933363330
# 5268756172696468736933363430
# 526963636172646F736934323230
# 526963636F736933313030
# 526979616A736933313030
# 526F62796E736931303630
# 526F647269676F736933303130
# 52756268616E736933363330
# 5275626965736933313030
# 52796C6965736933303130
# 5361616E7669736931303630
# 536164697161736933333430
# 536166697961736931303631
# 536166697961736932303630
# 53616768756E736931313030
# 53616966616464696E65736934333030
# 53616B696E61736933313030
# 53616D6172736933313030
# 53616D65657261736932303630
# 53617476656572736934323230
# 5365616E65736931313031
# 536861646F77736934323230
# 5368616E65736931303630
# 5368616E6E6F6E736934323230
# 53686175727961736932303630
# 53686177736931303630
# 536861796E65736933363330
# 5368657277796E736933333430
# 53686F6C61736934323230
# 53696E656964696E736934323230
# 536972696F6C736933303130
# 536F6D617961736932303630
# 536F6D6D6572736933363430
# 536F6E6E69736933333430
# 536F756C736933303130
# 5374657068616E6965736931303630
# 5375727961736932303630
# 537573616E736933333430
# 546169736861736934333030
# 54616C6F6E736933333430
# 54616E6E6572736934323230
# 54617261736933313030
# 54617465736933303130
# 5461797965736933363430
# 54686F6D6173736934323230
# 5469656768616E736933363430
# 54696666616E79736931303630
# 54797261736934333030
# 557262616E736933363330
# 557269736933363430
# 5665726F6E696B61736931313030
# 566963746F7279736934323230
# 56696B746F726961736934333030
# 566C616469736C6176736931313030
# 576172646168736934323230
# 59616E67736931303630
# 596173696E736933363430
# 5975736933333430
# 5A616368657279736933313030
# 5A61696E65736934323230
# 5A616B69797961736933363430
# 5A616E646572736933313030
# 5A61796E6162736932303630
# 5A61796E65736933313030
# 5A65696E6162736933313030
# 5A656E697468736934323230
# 5A657068736933333430
# 5A68656E736934333030
# 5A6964616E65736934333030
# 5A696E746F736931303630

# %%
abc = "With three words"
stuff = abc.split()
print(len(stuff))
# Out:
# 3
